# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("big_mart.csv")
print(df)
# Out:
#      ProductID  Weight FatContent  ProductVisibility         ProductType  \
# 0        FDW58  20.750    Low Fat           0.007565         Snack Foods
# 1        FDW14   8.300        reg           0.038428               Dairy
# 2        NCN55  14.600    Low Fat           0.099575              Others
# 3        FDQ58   7.315    Low Fat           0.015388         Snack Foods
# 4        FDY38     NaN    Regular           0.118599               Dairy
# ...        ...     ...        ...                ...                 ...
# 5676     FDB58  10.500    Regular           0.013496         Snack Foods
# 5677     FDD47   7.600    Regular           0.142991       Starchy Foods
# 5678     NCO17  10.000    Low Fat           0.073529  Health and Hygiene
# 5679     FDJ26  15.300    Regular           0.000000              Canned
# 5680     FDU37   9.500    Regular           0.104720              Canned
#
#            MRP OutletID  EstablishmentYear OutletSize LocationType  \
# ...

# %%
df.head()
# Out:
#   ProductID  Weight FatContent  ProductVisibility  ProductType       MRP  \
# 0     FDW58  20.750    Low Fat           0.007565  Snack Foods  107.8622
# 1     FDW14   8.300        reg           0.038428        Dairy   87.3198
# 2     NCN55  14.600    Low Fat           0.099575       Others  241.7538
# 3     FDQ58   7.315    Low Fat           0.015388  Snack Foods  155.0340
# 4     FDY38     NaN    Regular           0.118599        Dairy  234.2300
#
#   OutletID  EstablishmentYear OutletSize LocationType         OutletType
# 0   OUT049               1999     Medium       Tier 1  Supermarket Type1
# 1   OUT017               2007        NaN       Tier 2  Supermarket Type1
# 2   OUT010               1998        NaN       Tier 3      Grocery Store
# 3   OUT017               2007        NaN       Tier 2  Supermarket Type1
# 4   OUT027               1985     Medium       Tier 3  Supermarket Type3

# %%
df.tail()
# Out:
#      ProductID  Weight FatContent  ProductVisibility         ProductType  \
# 5676     FDB58    10.5    Regular           0.013496         Snack Foods
# 5677     FDD47     7.6    Regular           0.142991       Starchy Foods
# 5678     NCO17    10.0    Low Fat           0.073529  Health and Hygiene
# 5679     FDJ26    15.3    Regular           0.000000              Canned
# 5680     FDU37     9.5    Regular           0.104720              Canned
#
#            MRP OutletID  EstablishmentYear OutletSize LocationType  \
# 5676  141.3154   OUT046               1997      Small       Tier 1
# 5677  169.1448   OUT018               2009     Medium       Tier 3
# 5678  118.7440   OUT045               2002        NaN       Tier 2
# 5679  214.6218   OUT017               2007        NaN       Tier 2
# 5680   79.7960   OUT045               2002        NaN       Tier 2
#
#              OutletType
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (5681, 11)

# %%
df.size
# Out:
# 62491

# %%
rows=df.count()
print(rows)
# Out:
# ProductID            5681
# Weight               4705
# FatContent           5681
# ProductVisibility    5681
# ProductType          5681
# MRP                  5681
# OutletID             5681
# EstablishmentYear    5681
# OutletSize           4075
# LocationType         5681
# OutletType           5681
# dtype: int64

# %%
rows.mean()
# Out:
# 5446.272727272727

# %%
rows.median()
# Out:
# 5681.0

# %%
rows.std()
# Out:
# 540.9016714540807

# %%
df["MRP"].max
# Out:
# <bound method Series.max of 0       107.8622
# 1        87.3198
# 2       241.7538
# 3       155.0340
# 4       234.2300
#           ...
# 5676    141.3154
# 5677    169.1448
# 5678    118.7440
# 5679    214.6218
# 5680     79.7960
# Name: MRP, Length: 5681, dtype: float64>

# %%
df[["ProductType","MRP"]]
# Out:
#              ProductType       MRP
# 0            Snack Foods  107.8622
# 1                  Dairy   87.3198
# 2                 Others  241.7538
# 3            Snack Foods  155.0340
# 4                  Dairy  234.2300
# ...                  ...       ...
# 5676         Snack Foods  141.3154
# 5677       Starchy Foods  169.1448
# 5678  Health and Hygiene  118.7440
# 5679              Canned  214.6218
# 5680              Canned   79.7960
#
# [5681 rows x 2 columns]

# %%
df.describe()
# Out:
#             Weight  ProductVisibility          MRP  EstablishmentYear
# count  4705.000000        5681.000000  5681.000000        5681.000000
# mean     12.695633           0.065684   141.023273        1997.828903
# std       4.664849           0.051252    61.809091           8.372256
# min       4.555000           0.000000    31.990000        1985.000000
# 25%       8.645000           0.027047    94.412000        1987.000000
# 50%      12.500000           0.054154   141.415400        1999.000000
# 75%      16.700000           0.093463   186.026600        2004.000000
# max      21.350000           0.323637   266.588400        2009.000000

# %%
import matplotlib.pyplot as plt

# %%
df=pd.DataFrame(df)

# %%
df
# Out:
#      ProductID  Weight FatContent  ProductVisibility         ProductType  \
# 0        FDW58  20.750    Low Fat           0.007565         Snack Foods
# 1        FDW14   8.300        reg           0.038428               Dairy
# 2        NCN55  14.600    Low Fat           0.099575              Others
# 3        FDQ58   7.315    Low Fat           0.015388         Snack Foods
# 4        FDY38     NaN    Regular           0.118599               Dairy
# ...        ...     ...        ...                ...                 ...
# 5676     FDB58  10.500    Regular           0.013496         Snack Foods
# 5677     FDD47   7.600    Regular           0.142991       Starchy Foods
# 5678     NCO17  10.000    Low Fat           0.073529  Health and Hygiene
# 5679     FDJ26  15.300    Regular           0.000000              Canned
# 5680     FDU37   9.500    Regular           0.104720              Canned
#
#            MRP OutletID  EstablishmentYear OutletSize LocationType  \
# ...

# %%
y=df["ProductType"]
x=df["MRP"]
plt.bar(x,y,label="Mart Sales",color="red")
plt.xlabel("MRP")
plt.ylabel("ProductType")
plt.title("BIG MART SALES DATASET")
plt.show()

# %%
df
# Out:
#      ProductID  Weight FatContent  ProductVisibility         ProductType  \
# 0        FDW58  20.750    Low Fat           0.007565         Snack Foods
# 1        FDW14   8.300        reg           0.038428               Dairy
# 2        NCN55  14.600    Low Fat           0.099575              Others
# 3        FDQ58   7.315    Low Fat           0.015388         Snack Foods
# 4        FDY38     NaN    Regular           0.118599               Dairy
# ...        ...     ...        ...                ...                 ...
# 5676     FDB58  10.500    Regular           0.013496         Snack Foods
# 5677     FDD47   7.600    Regular           0.142991       Starchy Foods
# 5678     NCO17  10.000    Low Fat           0.073529  Health and Hygiene
# 5679     FDJ26  15.300    Regular           0.000000              Canned
# 5680     FDU37   9.500    Regular           0.104720              Canned
#
#            MRP OutletID  EstablishmentYear OutletSize LocationType  \
# ...

# %%
x=df["OutletID"]
plt.hist(x,bins=None,histtype="bar",rwidth=0.5,color='blue')
# Out:
# (array([620., 617., 370., 624., 620., 618., 619., 352., 621., 620.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
df
# Out:
#      ProductID  Weight FatContent  ProductVisibility         ProductType  \
# 0        FDW58  20.750    Low Fat           0.007565         Snack Foods
# 1        FDW14   8.300        reg           0.038428               Dairy
# 2        NCN55  14.600    Low Fat           0.099575              Others
# 3        FDQ58   7.315    Low Fat           0.015388         Snack Foods
# 4        FDY38     NaN    Regular           0.118599               Dairy
# ...        ...     ...        ...                ...                 ...
# 5676     FDB58  10.500    Regular           0.013496         Snack Foods
# 5677     FDD47   7.600    Regular           0.142991       Starchy Foods
# 5678     NCO17  10.000    Low Fat           0.073529  Health and Hygiene
# 5679     FDJ26  15.300    Regular           0.000000              Canned
# 5680     FDU37   9.500    Regular           0.104720              Canned
#
#            MRP OutletID  EstablishmentYear OutletSize LocationType  \
# ...

# %%
slices=[50,14,24,16]
depts=["ProductID","ProductType","MRP","ProductVisibility"]
cols=["cyan","red","yellow","blue"]
plt.pie(slices,labels=depts,colors=cols,startangle=90,explode=(0,0.2,0,0),shadow=True,autopct="%.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x17d50b4cd40>,
# ...
#  [Text(-1.0979931067756419, 0.06641639461137665, 'ProductID'),
#   Text(0.38675388956308576, -1.2411371515299285, 'ProductType'),
#   Text(1.0919797562557798, -0.1325903915356152, 'MRP'),
#   Text(0.5111955067851865, 0.9740016190143815, 'ProductVisibility')],
#  [Text(-0.5989053309685318, 0.03622712433347817, '48.1%'),
#   Text(0.23800239357728353, -0.7637767086338022, '13.5%'),
#   Text(0.5956253215940617, -0.07232203174669918, '23.1%'),
#   Text(0.27883391279191994, 0.5312736103714808, '15.4%')])

# %%
df
# Out:
#      ProductID  Weight FatContent  ProductVisibility         ProductType  \
# 0        FDW58  20.750    Low Fat           0.007565         Snack Foods
# 1        FDW14   8.300        reg           0.038428               Dairy
# 2        NCN55  14.600    Low Fat           0.099575              Others
# 3        FDQ58   7.315    Low Fat           0.015388         Snack Foods
# 4        FDY38     NaN    Regular           0.118599               Dairy
# ...        ...     ...        ...                ...                 ...
# 5676     FDB58  10.500    Regular           0.013496         Snack Foods
# 5677     FDD47   7.600    Regular           0.142991       Starchy Foods
# 5678     NCO17  10.000    Low Fat           0.073529  Health and Hygiene
# 5679     FDJ26  15.300    Regular           0.000000              Canned
# 5680     FDU37   9.500    Regular           0.104720              Canned
#
#            MRP OutletID  EstablishmentYear OutletSize LocationType  \
# ...

# %%
y=df["OutletID"]
x=df["EstablishmentYear"]
plt.plot(x,y,"black")
